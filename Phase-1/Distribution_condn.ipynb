# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
np.random.seed(42)

# standard normal distribution 
portfolio_returns = np.random.normal(loc=0, scale=1, size=1000)

## calculate the kurtosis
from scipy.stats import kurtosis
kurt_value = kurtosis(portfolio_returns)
print(f"Kurtosis : {kurt_value:.2f}")

sns.histplot(portfolio_returns, bins=30, kde=True)
plt.title(f"Portfolio Returns Distribution (Kurtosis: {kurt_value:.2f})")
plt.xlabel('Returns')
plt.ylabel('Frequency')
plt.show()
# Out:
# Kurtosis : 0.07

# %%
np.random.seed(42)

# standard normal distribution 
## adding extreme values
portfolio_returns = np.random.normal(loc=0, scale=50, size=50)

## calculate the kurtosis
from scipy.stats import kurtosis
kurt_value = kurtosis(portfolio_returns)
print(f"Kurtosis : {kurt_value:.2f}")

sns.histplot(portfolio_returns, bins=30, kde=True)
plt.title(f"Portfolio Returns Distribution (Kurtosis: {kurt_value:.2f})")
plt.xlabel('Returns')
plt.ylabel('Frequency')
plt.show()
# Out:
# Kurtosis : -0.45

# %%
np.random.seed(42)

# standard normal distribution 
portfolio_returns = np.random.normal(loc=1000, scale=1, size=10000)

## calculate the kurtosis
from scipy.stats import kurtosis
kurt_value = kurtosis(portfolio_returns)
print(f"Kurtosis : {kurt_value:.2f}")

sns.histplot(portfolio_returns, bins=30, kde=True)
plt.title(f"Portfolio Returns Distribution (Kurtosis: {kurt_value:.2f})")
plt.xlabel('Returns')
plt.ylabel('Frequency')
plt.show()
# Out:
# Kurtosis : 0.03
